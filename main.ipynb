# %% [markdown]
# # Cleaning and Analysis of Craigslist Used Car Postings
# Data retrieved from [Kaggle](https://www.kaggle.com/datasets/austinreese/craigslist-carstrucks-data), due to the dataset being to large to upload to github, manual download is required. Place 'vehicles.csv' in data folder.
#
# Uses : ![Jupyter Notebook](https://img.shields.io/badge/jupyter-%23FA0F00.svg?style=for-the-badge&logo=jupyter&logoColor=white)![Python](https://img.shields.io/badge/python-3670A0?style=for-the-badge&logo=python&logoColor=ffdd54)![Matplotlib](https://img.shields.io/badge/Matplotlib-%23ffffff.svg?style=for-the-badge&logo=Matplotlib&logoColor=black)![NumPy](https://img.shields.io/badge/numpy-%23013243.svg?style=for-the-badge&logo=numpy&logoColor=white)![Pandas](https://img.shields.io/badge/pandas-%23150458.svg?style=for-the-badge&logo=pandas&logoColor=white)

# %%
import pandas as pd
import os

# %%
data = pd.read_csv("data/vehicles.csv",header=0,index_col=0)
data
# Out:
#                                                           url  \
# id
# 7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...                                                       ...
# 7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                             region                         region_url  price  \
# id
# 7222695916                prescott    https://prescott.craigslist.org   6000
# 7218891961            fayetteville       https://fayar.craigslist.org  11900
# 7221797935            florida keys        https://keys.craigslist.org  21000
# 7222270760  worcester / central MA   https://worcester.craigslist.org   1500
# 7210384030              greensboro  https://greensboro.craigslist.org   4900
# ...                            ...                                ...    ...
# 7301591192                 wyoming     https://wyoming.craigslist.org  23590
# 7301591187                 wyoming     https://wyoming.craigslist.org  30590
# 7301591147                 wyoming     https://wyoming.craigslist.org  34990
# 7301591140                 wyoming     https://wyoming.craigslist.org  28990
# 7301591129                 wyoming     https://wyoming.craigslist.org  30590
#
#               year manufacturer                     model condition  \
# id
# 7222695916     NaN          NaN                       NaN       NaN
# 7218891961     NaN          NaN                       NaN       NaN
# 7221797935     NaN          NaN                       NaN       NaN
# 7222270760     NaN          NaN                       NaN       NaN
# 7210384030     NaN          NaN                       NaN       NaN
# ...            ...          ...                       ...       ...
# 7301591192  2019.0       nissan         maxima s sedan 4d      good
# 7301591187  2020.0        volvo  s60 t5 momentum sedan 4d      good
# 7301591147  2020.0     cadillac          xt4 sport suv 4d      good
# 7301591140  2018.0        lexus           es 350 sedan 4d      good
# 7301591129  2019.0          bmw  4 series 430i gran coupe      good
#
#               cylinders    fuel  ...  size       type paint_color  \
# id                               ...
# 7222695916          NaN     NaN  ...   NaN        NaN         NaN
# 7218891961          NaN     NaN  ...   NaN        NaN         NaN
# 7221797935          NaN     NaN  ...   NaN        NaN         NaN
# 7222270760          NaN     NaN  ...   NaN        NaN         NaN
# 7210384030          NaN     NaN  ...   NaN        NaN         NaN
# ...                 ...     ...  ...   ...        ...         ...
# 7301591192  6 cylinders     gas  ...   NaN      sedan         NaN
# 7301591187          NaN     gas  ...   NaN      sedan         red
# 7301591147          NaN  diesel  ...   NaN  hatchback       white
# 7301591140  6 cylinders     gas  ...   NaN      sedan      silver
# 7301591129          NaN     gas  ...   NaN      coupe         NaN
#
#                                                     image_url  \
# id
# 7222695916                                                NaN
# 7218891961                                                NaN
# 7221797935                                                NaN
# 7222270760                                                NaN
# 7210384030                                                NaN
# ...                                                       ...
# 7301591192  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 7301591187  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 7301591147  https://images.craigslist.org/00L0L_farM7bxnxR...
# 7301591140  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 7301591129  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                                   description county state  \
# id
# 7222695916                                                NaN    NaN    az
# 7218891961                                                NaN    NaN    ar
# 7221797935                                                NaN    NaN    fl
# 7222270760                                                NaN    NaN    ma
# 7210384030                                                NaN    NaN    nc
# ...                                                       ...    ...   ...
# 7301591192  Carvana is the safer way to buy a car During t...    NaN    wy
# 7301591187  Carvana is the safer way to buy a car During t...    NaN    wy
# 7301591147  Carvana is the safer way to buy a car During t...    NaN    wy
# 7301591140  Carvana is the safer way to buy a car During t...    NaN    wy
# 7301591129  Carvana is the safer way to buy a car During t...    NaN    wy
#
#                   lat       long              posting_date
# id
# 7222695916        NaN        NaN                       NaN
# 7218891961        NaN        NaN                       NaN
# 7221797935        NaN        NaN                       NaN
# 7222270760        NaN        NaN                       NaN
# 7210384030        NaN        NaN                       NaN
# ...               ...        ...                       ...
# 7301591192  33.786500 -84.445400  2021-04-04T03:21:31-0600
# 7301591187  33.786500 -84.445400  2021-04-04T03:21:29-0600
# 7301591147  33.779214 -84.411811  2021-04-04T03:21:17-0600
# 7301591140  33.786500 -84.445400  2021-04-04T03:21:11-0600
# 7301591129  33.779214 -84.411811  2021-04-04T03:21:07-0600
#
# [426880 rows x 25 columns]

# %% [markdown]
# To start with we'll look at how much of the data is invalid from the start.

# %%
nullCount = pd.DataFrame(columns=["NaNCount","NaN%"],index=data.columns)
for col in data.columns:
	count = len(data) - len(data[col].dropna())
	percent = (count / len(data)) * 100.0
	nullCount.loc[col] = [count,percent]

nullCount.sort_values(by="NaNCount",axis="index", inplace=True)
nullCount
# Out:
#              NaNCount       NaN%
# url                 0        0.0
# region              0        0.0
# region_url          0        0.0
# price               0        0.0
# state               0        0.0
# image_url          68    0.01593
# posting_date       68    0.01593
# description        70   0.016398
# year             1205   0.282281
# transmission     2556   0.598763
# fuel             3013   0.705819
# odometer         4400   1.030735
# model            5277   1.236179
# lat              6549   1.534155
# long             6549   1.534155
# title_status     8242   1.930753
# manufacturer    17646   4.133714
# type            92858  21.752717
# paint_color    130203  30.501078
# drive          130567  30.586347
# VIN            161042  37.725356
# condition      174104  40.785232
# cylinders      177678   41.62247
# size           306361  71.767476
# county         426880      100.0

# %% [markdown]
# Given that the 'county' column is always null, we can safely delete it.

# %%
_ = data.drop("county", inplace=True, axis = 1)

# %% [markdown]
# Next, we'll look at trimming outliers

# %%
def _forEachPrice(x,L,R):
	if x < L or x > R:
		return None
	else:
		return x

def removeOutliers(series: pd.Series,inplace = False):
	if inplace == False:
		series = series.copy()
	Q1 = series.quantile(0.25)
	Q3 = series.quantile(0.75)
	IQR = Q3 - Q1
	L = Q1 - 1.5 * IQR
	R = Q3 + 1.5 * IQR
	series = series.apply(_forEachPrice, args=(L,R,))
	return series

# %%
priceWithoutOutliers = removeOutliers(data['price'])
print("Nulled " , len(data['price'].dropna()) - len(priceWithoutOutliers.dropna()), " values.")
# Out:
# Nulled  8177  values.

# %% [markdown]
# Posting dates are stored at strings with the format 'YYYY-MM-DDTHH:MM:SS-????', we'll want them in a datetime format for future use.

# %%
#Due to long conversion times, caching is nesesary
cachePath = "data/postingDates.cache"
if os.path.exists(cachePath):
	postingDates = pd.read_pickle(cachePath)
else:
	# WARNING this cell takes a long time to run, my example takes 9 minutes
	postingDates = pd.to_datetime(data["posting_date"],infer_datetime_format=True)
	postingDates.to_pickle(cachePath)

# %%
postingDates
# Out:
# id
# 7222695916                          NaN
# 7218891961                          NaN
# 7221797935                          NaN
# 7222270760                          NaN
# 7210384030                          NaN
#                         ...
# 7301591192    2021-04-04 03:21:31-06:00
# 7301591187    2021-04-04 03:21:29-06:00
# 7301591147    2021-04-04 03:21:17-06:00
# 7301591140    2021-04-04 03:21:11-06:00
# 7301591129    2021-04-04 03:21:07-06:00
# Name: posting_date, Length: 426880, dtype: object
